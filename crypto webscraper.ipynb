# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15', #if you want to some of the column change 5000 into howmany you want
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '6832a2f5-ca2a-4533-8755-df580be7882f',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2025-09-26T12:10:21.006Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 9511}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 12393, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


pd.set_option('display.max_column', None)
pd.set_option('display.max_rows', None)

# %%
df=pd.json_normalize(data['data'])
df['timestamp']=pd.to_datetime('now')
df
# Out:
#        id         name symbol         slug  num_market_pairs  \
# 0       1      Bitcoin    BTC      bitcoin             12393
# 1    1027     Ethereum    ETH     ethereum             10834
# 2     825  Tether USDt   USDT       tether            149559
# 3      52          XRP    XRP          xrp              1711
# 4    1839          BNB    BNB          bnb              2762
# 5    5426       Solana    SOL       solana              1008
# 6    3408         USDC   USDC     usd-coin             32165
# 7      74     Dogecoin   DOGE     dogecoin              1314
# 8    1958         TRON    TRX         tron              1235
# 9    2010      Cardano    ADA      cardano              1591
# 10  29470  Ethena USDe   USDe  ethena-usde               219
# 11  32196  Hyperliquid   HYPE  hyperliquid               160
# 12   1975    Chainlink   LINK    chainlink              2099
# 13   5805    Avalanche   AVAX    avalanche               976
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)
        df2 = pd.json_normalize(data['data'])
        df2['Timestamp'] = pd.to_datetime('now')
        df = df.append(df2)
        
         # Use this if you want to create a csv and append data to it
        #df = pd.json_normalize(data['data'])
        #df['timestamp'] = pd.to_datetime('now')
        #df
        #if not os.path.isfile(r'E:\Practice\API.csv'):
         #   df.to_csv(r'E:\Practice\API.csv', header='column_names')
        #else:
         #   df.to_csv(r'E:\Practice\API.csv', mode='a', header=False)
        
    #Then to read in the file: df = pd.read_csv(r'E:\Practice\API.csv')

# %%
import os 
from time import time
from time import sleep

for i in range(200):
    api_runner()
    print("API runnner completed")
    sleep(60)
exit()

# %%
#df72 = pd.read_csv(r'E:\Practice\API.csv')
#df72

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df
# Out:
#        id         name symbol         slug  num_market_pairs  \
# 0       1      Bitcoin    BTC      bitcoin             12393
# 1    1027     Ethereum    ETH     ethereum             10834
# 2     825  Tether USDt   USDT       tether            149559
# 3      52          XRP    XRP          xrp              1711
# 4    1839          BNB    BNB          bnb              2762
# 5    5426       Solana    SOL       solana              1008
# 6    3408         USDC   USDC     usd-coin             32165
# 7      74     Dogecoin   DOGE     dogecoin              1314
# 8    1958         TRON    TRX         tron              1235
# 9    2010      Cardano    ADA      cardano              1591
# 10  29470  Ethena USDe   USDe  ethena-usde               219
# 11  32196  Hyperliquid   HYPE  hyperliquid               160
# 12   1975    Chainlink   LINK    chainlink              2099
# 13   5805    Avalanche   AVAX    avalanche               976
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.23519                      -2.23537
# Ethereum                         0.46562                      -2.92813
# Tether USDt                      0.00408                       0.02175
# XRP                              0.63056                      -3.36095
# BNB                              0.18777                      -4.87462
# Solana                           0.61948                      -4.49946
# USDC                            -0.00765                      -0.03586
# Dogecoin                         0.54372                      -3.35995
# TRON                             0.36519                       0.87713
# Cardano                          0.13814                      -2.69083
# Ethena USDe                      0.01592                       0.00360
# Hyperliquid                     -0.27938                      -1.70611
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.23519
#              quote.USD.percent_change_24h    -2.23537
#              quote.USD.percent_change_7d     -6.34989
#              quote.USD.percent_change_30d    -1.94653
#              quote.USD.percent_change_60d    -8.25723
#              quote.USD.percent_change_90d     1.58291
# Ethereum     quote.USD.percent_change_1h      0.46562
#              quote.USD.percent_change_24h    -2.92813
#              quote.USD.percent_change_7d    -13.74619
#              quote.USD.percent_change_30d   -15.38342
#              quote.USD.percent_change_60d     0.52783
#              quote.USD.percent_change_90d    60.60257
# Tether USDt  quote.USD.percent_change_1h      0.00408
#              quote.USD.percent_change_24h     0.02175
#              quote.USD.percent_change_7d      0.01143
#              quote.USD.percent_change_30d     0.05763
#              quote.USD.percent_change_60d     0.05736
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.23519
#             quote.USD.percent_change_24h  -2.23537
#             quote.USD.percent_change_7d   -6.34989
#             quote.USD.percent_change_30d  -1.94653
#             quote.USD.percent_change_60d  -8.25723
#             quote.USD.percent_change_90d   1.58291
# Ethereum    quote.USD.percent_change_1h    0.46562
#             quote.USD.percent_change_24h  -2.92813
#             quote.USD.percent_change_7d  -13.74619
#             quote.USD.percent_change_30d -15.38342
#             quote.USD.percent_change_60d   0.52783
#             quote.USD.percent_change_90d  60.60257
# Tether USDt quote.USD.percent_change_1h    0.00408
#             quote.USD.percent_change_24h   0.02175
#             quote.USD.percent_change_7d    0.01143
#             quote.USD.percent_change_30d   0.05763
#             quote.USD.percent_change_60d   0.05736
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))
df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.23519
# 1       Bitcoin  quote.USD.percent_change_24h  -2.23537
# 2       Bitcoin   quote.USD.percent_change_7d  -6.34989
# 3       Bitcoin  quote.USD.percent_change_30d  -1.94653
# 4       Bitcoin  quote.USD.percent_change_60d  -8.25723
# 5       Bitcoin  quote.USD.percent_change_90d   1.58291
# 6      Ethereum   quote.USD.percent_change_1h   0.46562
# 7      Ethereum  quote.USD.percent_change_24h  -2.92813
# 8      Ethereum   quote.USD.percent_change_7d -13.74619
# 9      Ethereum  quote.USD.percent_change_30d -15.38342
# 10     Ethereum  quote.USD.percent_change_60d   0.52783
# 11     Ethereum  quote.USD.percent_change_90d  60.60257
# 12  Tether USDt   quote.USD.percent_change_1h   0.00408
# 13  Tether USDt  quote.USD.percent_change_24h   0.02175
# 14  Tether USDt   quote.USD.percent_change_7d   0.01143
# 15  Tether USDt  quote.USD.percent_change_30d   0.05763
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.23519
# 1       Bitcoin  quote.USD.percent_change_24h  -2.23537
# 2       Bitcoin   quote.USD.percent_change_7d  -6.34989
# 3       Bitcoin  quote.USD.percent_change_30d  -1.94653
# 4       Bitcoin  quote.USD.percent_change_60d  -8.25723
# 5       Bitcoin  quote.USD.percent_change_90d   1.58291
# 6      Ethereum   quote.USD.percent_change_1h   0.46562
# 7      Ethereum  quote.USD.percent_change_24h  -2.92813
# 8      Ethereum   quote.USD.percent_change_7d -13.74619
# 9      Ethereum  quote.USD.percent_change_30d -15.38342
# 10     Ethereum  quote.USD.percent_change_60d   0.52783
# 11     Ethereum  quote.USD.percent_change_90d  60.60257
# 12  Tether USDt   quote.USD.percent_change_1h   0.00408
# 13  Tether USDt  quote.USD.percent_change_24h   0.02175
# 14  Tether USDt   quote.USD.percent_change_7d   0.01143
# 15  Tether USDt  quote.USD.percent_change_30d   0.05763
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   0.23519
# 1       Bitcoin            24h  -2.23537
# 2       Bitcoin             7d  -6.34989
# 3       Bitcoin            30d  -1.94653
# 4       Bitcoin            60d  -8.25723
# 5       Bitcoin            90d   1.58291
# 6      Ethereum             1h   0.46562
# 7      Ethereum            24h  -2.92813
# 8      Ethereum             7d -13.74619
# 9      Ethereum            30d -15.38342
# 10     Ethereum            60d   0.52783
# 11     Ethereum            90d  60.60257
# 12  Tether USDt             1h   0.00408
# 13  Tether USDt            24h   0.02175
# 14  Tether USDt             7d   0.01143
# 15  Tether USDt            30d   0.05763
# 16  Tether USDt            60d   0.05736
# 17  Tether USDt            90d   0.03734
# 18          XRP             1h   0.63056
# 19          XRP            24h  -3.36095
# 20          XRP             7d -10.30730
# 21          XRP            30d  -9.15835
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change',y= 'values',hue='name',data=df7, kind='point')

# %%
df_btc = df.query("name == 'Ethereum'")[['name','quote.USD.price','timestamp']]
print(df_btc)


df10
# Out:
#        name  quote.USD.price                  timestamp
# 1  Ethereum       3898.02224 2025-09-26 12:34:31.179543
#       name  quote.USD.price                  timestamp
# 0  Bitcoin     109095.51075 2025-09-26 12:34:31.179543

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='quote.USD.price'>
